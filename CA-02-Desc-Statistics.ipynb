# %% [markdown]
# ### Class Activity 02 — Descriptive Statistics (20 points)
#
# **Name:** First_Name Last_Name
# **Format:** Individual, in-class
# **Total points:** 20 (10 questions × 2 points)

# %% [markdown]
# **Purpose:** Guided practice for descriptive statistics using Python
# **Difficulty:** Intro / demonstration level
# **Instructions:**
# - For each question, write your solution **in the code cell directly below it**.
# - Use **core Python** and the `statistics` module. Some questions optionally use **pandas**.
# - Unless a question says **print**, storing results in variables is fine (but printing helps you verify).
# ---
# ### Setup (Run this cell first)

# %%
### Run this setup cell first
import statistics as stats

# Optional: pandas (only if installed/allowed by your instructor)
try:
    import pandas as pd
except ImportError:
    pd = None

print("Setup complete. statistics imported.", "pandas available." if pd is not None else "pandas not available.")
# Out:
# Setup complete. statistics imported. pandas available.

# %% [markdown]
# ---
#
# ### Dataset A (Use for Q1–Q10)
# We'll use this small dataset to keep calculations simple.

# %%
# Dataset A
data_a = [12, 15, 15, 18, 20, 22, 22, 25, 28, 30]
data_a

# %% [markdown]
# ### Q1 — Count
# Compute the number of observations in `data_a`.
# - Store it in a variable named `n_a`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Q2 — Minimum and Maximum
# Find the minimum and maximum of `data_a`.
# - Store them as `min_a` and `max_a`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Q3 — Range
# Compute the range of `data_a` (max − min).
# - Store it as `range_a`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Q4 — Mean (core Python)
# Compute the mean of `data_a` using `sum(data_a) / len(data_a)`.
# - Store it as `mean_a_core`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Q5 — Mean (statistics module)
# Compute the mean of `data_a` using `stats.mean(...)`.
# - Store it as `mean_a_stats`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Q6 — Median
# Compute the median of `data_a` using `stats.median(...)`.
# - Store it as `median_a`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Q7 — Mode
# Compute the mode of `data_a` using `stats.mode(...)`.
# - Store it as `mode_a`.
#
# Note: If you get an error, check whether your Python version handles multiple modes differently and discuss with your instructor.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Q8 — Variance (sample)
# Compute the **sample variance** of `data_a` using `stats.variance(...)`.
# - Store it as `var_a`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Q9 — Standard Deviation (sample)
# Compute the **sample standard deviation** of `data_a` using `stats.stdev(...)`.
# - Store it as `std_a`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Q10 — Sorting and basic interpretation
# Create a sorted version of `data_a`.
# - Store it as `sorted_a`.
# - Then print the first three and last three values of `sorted_a`.

# %%
# YOUR CODE HERE

# %%
! jupyter nbconvert CA-02-Desc-Statistics.ipynb --to html
# Out:
# [NbConvertApp] Converting notebook CA-02-Desc-Statistics.ipynb to html
# C:\Users\Raza\miniconda3\envs\dev\Lib\site-packages\nbformat\__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# [NbConvertApp] Writing 289143 bytes to CA-02-Desc-Statistics.html

# %% [markdown]
# ---
#
# ### The End
